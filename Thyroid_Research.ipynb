# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhileshSarangpure/Thyroid-Research/blob/main/Thyroid_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/LMHR.csv")
data
# Out:
#           TSH        T3        T4  Target
# 0    0.040225  0.229506  0.229280       0
# 1    0.068042  0.232931  0.152069       0
# 2    0.021102  0.236294  0.094590       0
# 3    0.017190  0.239596  0.055390       0
# 4    0.027838  0.242839  0.033018       0
# ..        ...       ...       ...     ...
# 202  0.062761  0.248312  0.210340       0
# 203  0.018624  0.247926  0.236863       0
# 204  0.186915  0.291139  0.276836       1
# 205  0.088687  0.113924  0.141243       0
# 206  0.038748  0.246914  0.334404       0
#
# [207 rows x 4 columns]

# %%
data.Target = np.where(data.Target >=1,'Positive', 'Negative')
data
# Out:
#           TSH        T3        T4    Target
# 0    0.040225  0.229506  0.229280  Negative
# 1    0.068042  0.232931  0.152069  Negative
# 2    0.021102  0.236294  0.094590  Negative
# 3    0.017190  0.239596  0.055390  Negative
# 4    0.027838  0.242839  0.033018  Negative
# ..        ...       ...       ...       ...
# 202  0.062761  0.248312  0.210340  Negative
# 203  0.018624  0.247926  0.236863  Negative
# 204  0.186915  0.291139  0.276836  Positive
# 205  0.088687  0.113924  0.141243  Negative
# 206  0.038748  0.246914  0.334404  Negative
#
# [207 rows x 4 columns]

# %%
#!pip install pycaret

# %%
#!pip install markupsafe==2.0.1

# %%
from pycaret.classification import *

# %%
exp_clf101 = setup(data = data, target = 'Target', session_id=123)
# Out:
#                                Description                     Value
# 0                               session_id                       123
# 1                                   Target                    Target
# 2                              Target Type                    Binary
# 3                            Label Encoded  Negative: 0, Positive: 1
# 4                            Original Data                  (207, 4)
# 5                           Missing Values                     False
# 6                         Numeric Features                         3
# 7                     Categorical Features                         0
# 8                         Ordinal Features                     False
# 9                High Cardinality Features                     False
# 10                 High Cardinality Method                      None
# 11                   Transformed Train Set                  (144, 3)
# 12                    Transformed Test Set                   (63, 3)
# ...

# %%
best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# dt               Decision Tree Classifier    0.9867  0.9926    1.00  0.9167
# lightgbm  Light Gradient Boosting Machine    0.9867  0.9890    1.00  0.9167
# ada                  Ada Boost Classifier    0.9800  0.9907    0.90  0.8167
# gbc          Gradient Boosting Classifier    0.9733  0.9907    0.85  0.8000
# rf               Random Forest Classifier    0.9729  0.9962    0.80  0.7167
# knn                K Neighbors Classifier    0.9657  0.9404    0.70  0.6167
# et                 Extra Trees Classifier    0.9657  0.9808    0.75  0.7000
# nb                            Naive Bayes    0.9376  0.8813    0.30  0.2167
# svm                   SVM - Linear Kernel    0.9376  0.0000    0.30  0.2167
# lda          Linear Discriminant Analysis    0.9376  0.9813    0.30  0.2167
# qda       Quadratic Discriminant Analysis    0.9305  0.8736    0.40  0.3000
# ...

# %%
exp_clf102 = setup(data = data, target = 'Target', session_id=123,
                  normalize = True, 
                  transformation = True)
# Out:
#                                Description                     Value
# 0                               session_id                       123
# 1                                   Target                    Target
# 2                              Target Type                    Binary
# 3                            Label Encoded  Negative: 0, Positive: 1
# 4                            Original Data                  (207, 4)
# 5                           Missing Values                     False
# 6                         Numeric Features                         3
# 7                     Categorical Features                         0
# 8                         Ordinal Features                     False
# 9                High Cardinality Features                     False
# 10                 High Cardinality Method                      None
# 11                   Transformed Train Set                  (144, 3)
# 12                    Transformed Test Set                   (63, 3)
# ...

# %%
best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# dt               Decision Tree Classifier    0.9867  0.9926    1.00  0.9167
# lightgbm  Light Gradient Boosting Machine    0.9867  0.9890    1.00  0.9167
# ada                  Ada Boost Classifier    0.9800  0.9945    0.90  0.8167
# gbc          Gradient Boosting Classifier    0.9800  0.9945    0.85  0.8500
# nb                            Naive Bayes    0.9729  0.9813    0.80  0.7167
# rf               Random Forest Classifier    0.9729  0.9981    0.80  0.7167
# qda       Quadratic Discriminant Analysis    0.9595  0.9709    0.60  0.5667
# lr                    Logistic Regression    0.9514  0.9852    0.50  0.4167
# knn                K Neighbors Classifier    0.9448  0.9346    0.60  0.4500
# et                 Extra Trees Classifier    0.9443  0.9808    0.55  0.5500
# ridge                    Ridge Classifier    0.9376  0.0000    0.15  0.2000
# ...

# %%
rf_model = create_model('rf')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9333  1.0000     1.0  0.5000  0.6667  0.6341  0.6814
# 1       0.9333  1.0000     0.0  0.0000  0.0000  0.0000  0.0000
# 2       1.0000  1.0000     1.0  1.0000  1.0000  1.0000  1.0000
# 3       0.9333  0.9808     1.0  0.6667  0.8000  0.7619  0.7845
# 4       1.0000  1.0000     1.0  1.0000  1.0000  1.0000  1.0000
# 5       1.0000  1.0000     1.0  1.0000  1.0000  1.0000  1.0000
# 6       1.0000  1.0000     1.0  1.0000  1.0000  1.0000  1.0000
# 7       1.0000  1.0000     1.0  1.0000  1.0000  1.0000  1.0000
# 8       1.0000  1.0000     1.0  1.0000  1.0000  1.0000  1.0000
# 9       0.9286  1.0000     0.0  0.0000  0.0000  0.0000  0.0000
# Mean    0.9729  0.9981     0.8  0.7167  0.7467  0.7396  0.7466
# Std     0.0333  0.0058     0.4  0.3948  0.3885  0.3889  0.3880
# INFO:logs:create_model_container: 15
# INFO:logs:master_model_container: 15
# INFO:logs:display_container: 3
# ...

# %%
evaluate_model(rf_model)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(rf_model, model_name = 'random_forest_model')
# Out:
# INFO:logs:Initializing save_model()
# INFO:logs:save_model(model=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False), model_name=random_forest_model, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
# ...

# %%
from google.colab import files
files.download('random_forest_model.pkl')
